# %%
from qiskit.circuit.library import EfficientSU2

n_qubits = 10
reps = 1

circuit = EfficientSU2(n_qubits, entanglement="pairwise", reps=reps)

circuit.decompose().draw("mpl", scale=0.7)

# %%
from qiskit.quantum_info import SparsePauliOp

observable = SparsePauliOp.from_sparse_list([("Z", [-1], 1.0)], num_qubits=n_qubits)

# %%
import numpy as np
from qiskit.circuit.library import UnitaryOverlap

# Generate random parameters
rng = np.random.default_rng(1234)
params = rng.uniform(-np.pi, np.pi, size=circuit.num_parameters)

# Assign the parameters to the circuit
assigned_circuit = circuit.assign_parameters(params)

# Add a barrier to prevent circuit optimization of mirrored operators
assigned_circuit.barrier()

# Construct mirror circuit
mirror_circuit = UnitaryOverlap(assigned_circuit, assigned_circuit)

mirror_circuit.decompose().draw("mpl", scale=0.7)

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService()

backend = service.least_busy(min_num_qubits=127)

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

pass_manager = generate_preset_pass_manager(
    optimization_level=3, backend=backend, seed_transpiler=1234
)
isa_circuit = pass_manager.run(mirror_circuit)

isa_circuit.draw("mpl", idle_wires=False, scale=0.7, fold=-1)
# Out:
# ---------------------------------------------------------------------------
# TranspilerError                           Traceback (most recent call last)
# Cell In[31], line 3
#       1 from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
# ----> 3 pass_manager = generate_preset_pass_manager(
#       4     optimization_level=3, backend=backend, seed_transpiler=1234
#       5 )
#       6 isa_circuit = pass_manager.run(mirror_circuit)
#       8 isa_circuit.draw("mpl", idle_wires=False, scale=0.7, fold=-1)
#
# File c:\Users\admin\.vscode\QuantumEnv\.venv\Lib\site-packages\qiskit\transpiler\preset_passmanagers\generate_preset_pass_manager.py:381, in generate_preset_pass_manager(optimization_level, backend, target, basis_gates, inst_map, coupling_map, instruction_durations, backend_properties, timing_constraints, initial_layout, layout_method, routing_method, translation_method, scheduling_method, approximation_degree, seed_transpiler, unitary_synthesis_method, unitary_synthesis_plugin_config, hls_config, init_method, optimization_method, dt, _skip_target)
#     379     pm = level_2_pass_manager(pm_config)
#     380 elif optimization_level == 3:
# --> 381     pm = level_3_pass_manager(pm_config)
#     382 else:
#     383     raise ValueError(f"Invalid optimization level {optimization_level}")
#
# File c:\Users\admin\.vscode\QuantumEnv\.venv\Lib\site-packages\qiskit\transpiler\preset_passmanagers\level3.py:90, in level_3_pass_manager(pass_manager_config)
#      87     layout = None
#      88     routing = None
# ---> 90 translation = plugin_manager.get_passmanager_stage(
#      91     "translation", translation_method, pass_manager_config, optimization_level=3
#      92 )
#      94 optimization = plugin_manager.get_passmanager_stage(
#      95     "optimization", optimization_method, pass_manager_config, optimization_level=3
#      96 )
#      97 if (coupling_map and not coupling_map.is_symmetric) or (
#      98     target is not None and target.get_non_global_operation_names(strict_direction=True)
#      99 ):
#
# File c:\Users\admin\.vscode\QuantumEnv\.venv\Lib\site-packages\qiskit\transpiler\preset_passmanagers\plugin.py:255, in PassManagerStagePluginManager.get_passmanager_stage(self, stage_name, plugin_name, pm_config, optimization_level)
#     251     return self._build_pm(
#     252         self.routing_plugins, stage_name, plugin_name, pm_config, optimization_level
#     253     )
#     254 elif stage_name == "translation":
# --> 255     return self._build_pm(
#     256         self.translation_plugins, stage_name, plugin_name, pm_config, optimization_level
#     257     )
#     258 elif stage_name == "optimization":
#     259     return self._build_pm(
#     260         self.optimization_plugins, stage_name, plugin_name, pm_config, optimization_level
#     261     )
#
# File c:\Users\admin\.vscode\QuantumEnv\.venv\Lib\site-packages\qiskit\transpiler\preset_passmanagers\plugin.py:278, in PassManagerStagePluginManager._build_pm(self, stage_obj, stage_name, plugin_name, pm_config, optimization_level)
#     269 def _build_pm(
#     270     self,
#     271     stage_obj: stevedore.ExtensionManager,
#    (...)
#     275     optimization_level: Optional[int] = None,
#     276 ):
#     277     if plugin_name not in stage_obj:
# --> 278         raise TranspilerError(f"Invalid plugin name {plugin_name} for stage {stage_name}")
#     279     plugin_obj = stage_obj[plugin_name]
#     280     return plugin_obj.obj.pass_manager(pm_config, optimization_level)
#
# TranspilerError: 'Invalid plugin name ibm_dynamic_circuits for stage translation'
